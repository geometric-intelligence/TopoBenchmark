# %%
import pandas as pd

df = pd.read_csv('/home/lev/projects/TopoBenchmarkX/tables/dataset_statistics.csv', index_col=0)
df = df[['dataset',	'domain', 'zero_cell',	'one_cell',	'two_cell',	'three_cell', 'num_hyperedges']]

# Sort by dataset and domain
df = df.sort_values(by=['domain', 'dataset'])


print(df.to_latex(index=False, escape=False, column_format='lllrrrrr'))
# Out:
# \begin{tabular}{lllrrrrr}
# \toprule
# dataset & domain & zero_cell & one_cell & two_cell & three_cell & num_hyperedges \\
# \midrule
# Cora & cell & 2708 & 5278 & 2648 & 0 & 0 \\
# IMDB-BINARY & cell & 19773 & 96531 & 77758 & 0 & 0 \\
# IMDB-MULTI & cell & 19502 & 98903 & 80901 & 0 & 0 \\
# MUTAG & cell & 3371 & 3721 & 538 & 0 & 0 \\
# NCI1 & cell & 122747 & 132753 & 14885 & 0 & 0 \\
# NCI109 & cell & 122494 & 132604 & 15042 & 0 & 0 \\
# PROTEINS & cell & 43471 & 81044 & 38773 & 0 & 0 \\
# PubMed & cell & 19717 & 44324 & 23605 & 0 & 0 \\
# REDDIT-BINARY & cell & 859254 & 995508 & 141218 & 0 & 0 \\
# ZINC & cell & 277864 & 298985 & 33121 & 0 & 0 \\
# amazon_ratings & cell & 24492 & 93050 & 68553 & 0 & 0 \\
# citeseer & cell & 3327 & 4552 & 1663 & 0 & 0 \\
# minesweeper & cell & 10000 & 39402 & 28955 & 0 & 0 \\
# roman_empire & cell & 22662 & 32927 & 10266 & 0 & 0 \\
# Cora & hypergraph & 2708 & 0 & 0 & 0 & 2708 \\
# IMDB-BINARY & hypergraph & 19773 & 0 & 0 & 0 & 19773 \\
# ...

# %%
df
# Out:
#      dataset      domain  zero_cell  one_cell  two_cell  three_cell  \
# 3   citeseer        cell       3327      4552      1663           0
# 10  citeseer  hypergraph       3327         0         0           0
# 2   citeseer  simplicial       3327      4552      1167         255
# 11       NaN        cell       2708      5278      2648           0
# 14       NaN        cell      19773     96531     77758           0
# 20       NaN        cell      19502     98903     80901           0
# 1        NaN        cell       3371      3721       538           0
# 24       NaN        cell     122747    132753     14885           0
# 35       NaN        cell     122494    132604     15042           0
# 15       NaN        cell      43471     81044     38773           0
# 32       NaN        cell      19717     44324     23605           0
# 42       NaN        cell     859254    995508    141218           0
# 31       NaN        cell     277864    298985     33121           0
# ...
