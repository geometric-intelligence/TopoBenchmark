# %% [markdown]
# # Implementing your own model

# %% [markdown]
# In this tutorial we show how to implement your own model and test it on a dataset.
#
# This particular example uses the MUTAG dataset, uses an hypergraph lifting to create hypergraphs, and defines a model to work on them.
#
# We train the model using the appropriate training and validation datasets, and finally test it on the test dataset.

# %% [markdown]
# ### <font color='289C4E'>Table of contents<font><a class='anchor' id='top'></a>
# &emsp;[1. Imports](##sec1)
#
# &emsp;[2. Configurations and utilities](##sec2)
#
# &emsp;[3. Loading the data](##sec3)
#
# &emsp;[4. Backbone definition](##sec4)
#
# &emsp;[5. Model initialization](##sec5)
#
# &emsp;[6. Training](##sec6)
#
# &emsp;[7. Testing the model](##sec7)

# %% [markdown]
# ## 1. Imports <a class="anchor" id="sec1"></a>

# %%
import lightning as pl
import torch
from omegaconf import OmegaConf

from topobenchmarkx.data.loaders import GraphLoader
from topobenchmarkx.data.preprocessor import PreProcessor
from topobenchmarkx.dataloader import TBXDataloader
from topobenchmarkx.evaluator import TBXEvaluator
from topobenchmarkx.loss import TBXLoss
from topobenchmarkx.model import TBXModel
from topobenchmarkx.nn.backbones.simplicial.sann import SANN
from topobenchmarkx.nn.wrappers.simplicial.sann_wrapper import SANNWrapper
from topobenchmarkx.nn.encoders.simple_encoder import SANNCellEncoder
from topobenchmarkx.nn.readouts.sann import SANNReadout
from topobenchmarkx.optimizer import TBXOptimizer

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## 2. Configurations and utilities <a class="anchor" id="sec2"></a>

# %% [markdown]
# Configurations can be specified using yaml files or directly specified in your code like in this example.

# %%
in_channels = 3
hidden_dim_1 = 2*32
hidden_dim_2 = 2*32
hidden_dim_readout = 2*32
out_channels = 1

loader_config = {
    "data_domain": "graph",
    "data_type": "TUDataset",
    "data_name": "PROTEINS",
    "data_dir": "./data/MUTAG/PROTEINS",
}

transform_config = {
"clique_lifting": {
        "transform_type": "lifting",
        "transform_name": "SimplicialCliqueLifting",
        "feature_lifting": "Duplicate",
        "all_ones": True,
        "complex_dim": 3
    },
"sann_encoding":{
        "transform_type": "data manipulation",
        "transform_name": "PrecomputeKHopFeatures",
        "max_hop": 2
    }
    
}

wrapper_config = {
    "out_channels": out_channels,
    "num_cell_dimensions": in_channels,
}

split_config = {
    "learning_setting": "inductive",
    "split_type": "k-fold",
    "data_seed": 0,
    "data_split_dir": "./data/PROTEINS/splits/",
    "k": 10,
}


readout_config = {
    "readout_name": "SANNReadout",
    "num_cell_dimensions": in_channels,
    "hidden_dim": hidden_dim_2,
    "hidden_dim_2": hidden_dim_readout,
    "out_channels": out_channels,
    "task_level": "graph",
    "pooling_type": "sum",
}

loss_config = {"task": "classification", "loss_type": "cross_entropy"}

evaluator_config = {"task": "classification",
                    "num_classes": out_channels+1, # If it's 1 we sum one so it works with TBXEvaluator
                    "metrics": ["accuracy", "precision", "recall"]}

optimizer_config = {"optimizer_id": "Adam",
                    "parameters":
                        {"lr": 1e-3,"weight_decay": 1e-4}
                    }

loader_config = OmegaConf.create(loader_config)
transform_config = OmegaConf.create(transform_config)
split_config = OmegaConf.create(split_config)
readout_config = OmegaConf.create(readout_config)
loss_config = OmegaConf.create(loss_config)
evaluator_config = OmegaConf.create(evaluator_config)
optimizer_config = OmegaConf.create(optimizer_config)

# %%
def wrapper(**factory_kwargs):
    def factory(backbone):
        return SANNWrapper(backbone, **factory_kwargs)
    return factory

# %% [markdown]
# ## 3. Loading the data <a class="anchor" id="sec3"></a>

# %% [markdown]
# In this example we use the MUTAG dataset. It is a graph dataset and we use the k-hop lifting to transform the graphs into hypergraphs.
#
# We invite you to check out the README of the [repository](https://github.com/pyt-team/TopoBenchmarkX) to learn more about the various liftings offered.

# %%
graph_loader = GraphLoader(loader_config)

dataset, dataset_dir = graph_loader.load()

preprocessor = PreProcessor(dataset, dataset_dir, transform_config, force_reload=True)
dataset_train, dataset_val, dataset_test = preprocessor.load_dataset_splits(split_config)
datamodule = TBXDataloader(dataset_train, dataset_val, dataset_test, batch_size=1)
# Out:
# Processing...
# torch.Size([81, 81]) torch.Size([81, 81])
# torch.Size([29, 29]) torch.Size([29, 29])
# torch.Size([46, 46]) torch.Size([46, 46])
# torch.Size([22, 22]) torch.Size([22, 22])
# torch.Size([17, 17]) torch.Size([17, 17])
# torch.Size([10, 10]) torch.Size([10, 10])
# torch.Size([46, 46]) torch.Size([46, 46])
# torch.Size([14, 14]) torch.Size([14, 14])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([14, 14]) torch.Size([14, 14])
# torch.Size([816, 816]) torch.Size([816, 816])
# torch.Size([491, 491]) torch.Size([491, 491])
# torch.Size([243, 243]) torch.Size([243, 243])
# torch.Size([139, 139]) torch.Size([139, 139])
# torch.Size([281, 281]) torch.Size([281, 281])
# torch.Size([40, 40]) torch.Size([40, 40])
# torch.Size([33, 33]) torch.Size([33, 33])
# torch.Size([17, 17]) torch.Size([17, 17])
# torch.Size([19, 19]) torch.Size([19, 19])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([15, 15]) torch.Size([15, 15])
# torch.Size([103, 103]) torch.Size([103, 103])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([20, 20]) torch.Size([20, 20])
# torch.Size([85, 85]) torch.Size([85, 85])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([36, 36]) torch.Size([36, 36])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([67, 67]) torch.Size([67, 67])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([41, 41]) torch.Size([41, 41])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([424, 424]) torch.Size([424, 424])
# torch.Size([85, 85]) torch.Size([85, 85])
# torch.Size([79, 79]) torch.Size([79, 79])
# torch.Size([8, 8]) torch.Size([8, 8])
# torch.Size([47, 47]) torch.Size([47, 47])
# torch.Size([23, 23]) torch.Size([23, 23])
# torch.Size([1012, 1012]) torch.Size([1012, 1012])
# torch.Size([534, 534]) torch.Size([534, 534])
# torch.Size([92, 92]) torch.Size([92, 92])
# torch.Size([43, 43]) torch.Size([43, 43])
# torch.Size([114, 114]) torch.Size([114, 114])
# torch.Size([27, 27]) torch.Size([27, 27])
# torch.Size([24, 24]) torch.Size([24, 24])
# torch.Size([10, 10]) torch.Size([10, 10])
# torch.Size([70, 70]) torch.Size([70, 70])
# torch.Size([22, 22]) torch.Size([22, 22])
# torch.Size([265, 265]) torch.Size([265, 265])
# torch.Size([107, 107]) torch.Size([107, 107])
# torch.Size([156, 156]) torch.Size([156, 156])
# torch.Size([34, 34]) torch.Size([34, 34])
# torch.Size([81, 81]) torch.Size([81, 81])
# torch.Size([16, 16]) torch.Size([16, 16])
# torch.Size([114, 114]) torch.Size([114, 114])
# torch.Size([48, 48]) torch.Size([48, 48])
# torch.Size([88, 88]) torch.Size([88, 88])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([86, 86]) torch.Size([86, 86])
# torch.Size([44, 44]) torch.Size([44, 44])
# torch.Size([25, 25]) torch.Size([25, 25])
# torch.Size([6, 6]) torch.Size([6, 6])
# torch.Size([116, 116]) torch.Size([116, 116])
# torch.Size([34, 34]) torch.Size([34, 34])
# torch.Size([25, 25]) torch.Size([25, 25])
# torch.Size([15, 15]) torch.Size([15, 15])
# torch.Size([47, 47]) torch.Size([47, 47])
# torch.Size([24, 24]) torch.Size([24, 24])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([66, 66]) torch.Size([66, 66])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([86, 86]) torch.Size([86, 86])
# torch.Size([31, 31]) torch.Size([31, 31])
# torch.Size([74, 74]) torch.Size([74, 74])
# torch.Size([34, 34]) torch.Size([34, 34])
# torch.Size([143, 143]) torch.Size([143, 143])
# torch.Size([25, 25]) torch.Size([25, 25])
# torch.Size([87, 87]) torch.Size([87, 87])
# torch.Size([41, 41]) torch.Size([41, 41])
# torch.Size([25, 25]) torch.Size([25, 25])
# torch.Size([14, 14]) torch.Size([14, 14])
# torch.Size([220, 220]) torch.Size([220, 220])
# torch.Size([104, 104]) torch.Size([104, 104])
# torch.Size([37, 37]) torch.Size([37, 37])
# torch.Size([20, 20]) torch.Size([20, 20])
# torch.Size([51, 51]) torch.Size([51, 51])
# torch.Size([22, 22]) torch.Size([22, 22])
# torch.Size([56, 56]) torch.Size([56, 56])
# torch.Size([28, 28]) torch.Size([28, 28])
# torch.Size([111, 111]) torch.Size([111, 111])
# torch.Size([15, 15]) torch.Size([15, 15])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([72, 72]) torch.Size([72, 72])
# torch.Size([42, 42]) torch.Size([42, 42])
# torch.Size([68, 68]) torch.Size([68, 68])
# torch.Size([15, 15]) torch.Size([15, 15])
# torch.Size([22, 22]) torch.Size([22, 22])
# torch.Size([15, 15]) torch.Size([15, 15])
# torch.Size([65, 65]) torch.Size([65, 65])
# torch.Size([39, 39]) torch.Size([39, 39])
# torch.Size([266, 266]) torch.Size([266, 266])
# torch.Size([48, 48]) torch.Size([48, 48])
# torch.Size([54, 54]) torch.Size([54, 54])
# torch.Size([31, 31]) torch.Size([31, 31])
# torch.Size([36, 36]) torch.Size([36, 36])
# torch.Size([20, 20]) torch.Size([20, 20])
# torch.Size([69, 69]) torch.Size([69, 69])
# torch.Size([20, 20]) torch.Size([20, 20])
# torch.Size([116, 116]) torch.Size([116, 116])
# torch.Size([37, 37]) torch.Size([37, 37])
# torch.Size([61, 61]) torch.Size([61, 61])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([19, 19]) torch.Size([19, 19])
# torch.Size([96, 96]) torch.Size([96, 96])
# torch.Size([34, 34]) torch.Size([34, 34])
# torch.Size([37, 37]) torch.Size([37, 37])
# torch.Size([14, 14]) torch.Size([14, 14])
# torch.Size([40, 40]) torch.Size([40, 40])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([53, 53]) torch.Size([53, 53])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([233, 233]) torch.Size([233, 233])
# torch.Size([52, 52]) torch.Size([52, 52])
# torch.Size([45, 45]) torch.Size([45, 45])
# torch.Size([23, 23]) torch.Size([23, 23])
# torch.Size([152, 152]) torch.Size([152, 152])
# torch.Size([80, 80]) torch.Size([80, 80])
# torch.Size([88, 88]) torch.Size([88, 88])
# torch.Size([15, 15]) torch.Size([15, 15])
# torch.Size([19, 19]) torch.Size([19, 19])
# torch.Size([12, 12]) torch.Size([12, 12])
# torch.Size([59, 59]) torch.Size([59, 59])
# torch.Size([44, 44]) torch.Size([44, 44])
# torch.Size([45, 45]) torch.Size([45, 45])
# torch.Size([24, 24]) torch.Size([24, 24])
# torch.Size([74, 74]) torch.Size([74, 74])
# torch.Size([37, 37]) torch.Size([37, 37])
# torch.Size([36, 36]) torch.Size([36, 36])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([55, 55]) torch.Size([55, 55])
# torch.Size([36, 36]) torch.Size([36, 36])
# torch.Size([150, 150]) torch.Size([150, 150])
# torch.Size([45, 45]) torch.Size([45, 45])
# torch.Size([120, 120]) torch.Size([120, 120])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([8, 8]) torch.Size([8, 8])
# torch.Size([1049, 1049]) torch.Size([1049, 1049])
# torch.Size([98, 98]) torch.Size([98, 98])
# torch.Size([106, 106]) torch.Size([106, 106])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([89, 89]) torch.Size([89, 89])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([39, 39]) torch.Size([39, 39])
# torch.Size([19, 19]) torch.Size([19, 19])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([44, 44]) torch.Size([44, 44])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([52, 52]) torch.Size([52, 52])
# torch.Size([24, 24]) torch.Size([24, 24])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([53, 53]) torch.Size([53, 53])
# torch.Size([39, 39]) torch.Size([39, 39])
# torch.Size([12, 12]) torch.Size([12, 12])
# torch.Size([8, 8]) torch.Size([8, 8])
# torch.Size([57, 57]) torch.Size([57, 57])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([77, 77]) torch.Size([77, 77])
# torch.Size([52, 52]) torch.Size([52, 52])
# torch.Size([39, 39]) torch.Size([39, 39])
# torch.Size([22, 22]) torch.Size([22, 22])
# torch.Size([44, 44]) torch.Size([44, 44])
# torch.Size([22, 22]) torch.Size([22, 22])
# torch.Size([323, 323]) torch.Size([323, 323])
# torch.Size([78, 78]) torch.Size([78, 78])
# torch.Size([340, 340]) torch.Size([340, 340])
# torch.Size([62, 62]) torch.Size([62, 62])
# torch.Size([108, 108]) torch.Size([108, 108])
# torch.Size([28, 28]) torch.Size([28, 28])
# torch.Size([28, 28]) torch.Size([28, 28])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([23, 23]) torch.Size([23, 23])
# torch.Size([15, 15]) torch.Size([15, 15])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([5, 5]) torch.Size([5, 5])
# torch.Size([128, 128]) torch.Size([128, 128])
# torch.Size([41, 41]) torch.Size([41, 41])
# torch.Size([44, 44]) torch.Size([44, 44])
# torch.Size([24, 24]) torch.Size([24, 24])
# torch.Size([160, 160]) torch.Size([160, 160])
# torch.Size([36, 36]) torch.Size([36, 36])
# torch.Size([78, 78]) torch.Size([78, 78])
# torch.Size([42, 42]) torch.Size([42, 42])
# torch.Size([107, 107]) torch.Size([107, 107])
# torch.Size([33, 33]) torch.Size([33, 33])
# torch.Size([110, 110]) torch.Size([110, 110])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([113, 113]) torch.Size([113, 113])
# torch.Size([58, 58]) torch.Size([58, 58])
# torch.Size([44, 44]) torch.Size([44, 44])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([75, 75]) torch.Size([75, 75])
# torch.Size([42, 42]) torch.Size([42, 42])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([14, 14]) torch.Size([14, 14])
# torch.Size([391, 391]) torch.Size([391, 391])
# torch.Size([59, 59]) torch.Size([59, 59])
# torch.Size([164, 164]) torch.Size([164, 164])
# torch.Size([50, 50]) torch.Size([50, 50])
# torch.Size([50, 50]) torch.Size([50, 50])
# torch.Size([30, 30]) torch.Size([30, 30])
# torch.Size([47, 47]) torch.Size([47, 47])
# torch.Size([22, 22]) torch.Size([22, 22])
# torch.Size([42, 42]) torch.Size([42, 42])
# torch.Size([22, 22]) torch.Size([22, 22])
# torch.Size([195, 195]) torch.Size([195, 195])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([23, 23]) torch.Size([23, 23])
# torch.Size([42, 42]) torch.Size([42, 42])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([72, 72]) torch.Size([72, 72])
# torch.Size([43, 43]) torch.Size([43, 43])
# torch.Size([81, 81]) torch.Size([81, 81])
# torch.Size([30, 30]) torch.Size([30, 30])
# torch.Size([97, 97]) torch.Size([97, 97])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([71, 71]) torch.Size([71, 71])
# torch.Size([40, 40]) torch.Size([40, 40])
# torch.Size([104, 104]) torch.Size([104, 104])
# torch.Size([28, 28]) torch.Size([28, 28])
# torch.Size([43, 43]) torch.Size([43, 43])
# torch.Size([24, 24]) torch.Size([24, 24])
# torch.Size([60, 60]) torch.Size([60, 60])
# torch.Size([12, 12]) torch.Size([12, 12])
# torch.Size([40, 40]) torch.Size([40, 40])
# torch.Size([17, 17]) torch.Size([17, 17])
# torch.Size([124, 124]) torch.Size([124, 124])
# torch.Size([35, 35]) torch.Size([35, 35])
# torch.Size([254, 254]) torch.Size([254, 254])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([75, 75]) torch.Size([75, 75])
# torch.Size([23, 23]) torch.Size([23, 23])
# torch.Size([39, 39]) torch.Size([39, 39])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([36, 36]) torch.Size([36, 36])
# torch.Size([20, 20]) torch.Size([20, 20])
# torch.Size([48, 48]) torch.Size([48, 48])
# torch.Size([25, 25]) torch.Size([25, 25])
# torch.Size([24, 24]) torch.Size([24, 24])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([101, 101]) torch.Size([101, 101])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([84, 84]) torch.Size([84, 84])
# torch.Size([50, 50]) torch.Size([50, 50])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([33, 33]) torch.Size([33, 33])
# torch.Size([5, 5]) torch.Size([5, 5])
# torch.Size([75, 75]) torch.Size([75, 75])
# torch.Size([42, 42]) torch.Size([42, 42])
# torch.Size([103, 103]) torch.Size([103, 103])
# torch.Size([62, 62]) torch.Size([62, 62])
# torch.Size([115, 115]) torch.Size([115, 115])
# torch.Size([42, 42]) torch.Size([42, 42])
# torch.Size([42, 42]) torch.Size([42, 42])
# torch.Size([23, 23]) torch.Size([23, 23])
# torch.Size([143, 143]) torch.Size([143, 143])
# torch.Size([45, 45]) torch.Size([45, 45])
# torch.Size([125, 125]) torch.Size([125, 125])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([216, 216]) torch.Size([216, 216])
# torch.Size([39, 39]) torch.Size([39, 39])
# torch.Size([49, 49]) torch.Size([49, 49])
# torch.Size([27, 27]) torch.Size([27, 27])
# torch.Size([95, 95]) torch.Size([95, 95])
# torch.Size([12, 12]) torch.Size([12, 12])
# torch.Size([156, 156]) torch.Size([156, 156])
# torch.Size([29, 29]) torch.Size([29, 29])
# torch.Size([256, 256]) torch.Size([256, 256])
# torch.Size([45, 45]) torch.Size([45, 45])
# torch.Size([56, 56]) torch.Size([56, 56])
# torch.Size([30, 30]) torch.Size([30, 30])
# torch.Size([67, 67]) torch.Size([67, 67])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([53, 53]) torch.Size([53, 53])
# torch.Size([30, 30]) torch.Size([30, 30])
# torch.Size([97, 97]) torch.Size([97, 97])
# torch.Size([41, 41]) torch.Size([41, 41])
# torch.Size([40, 40]) torch.Size([40, 40])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([89, 89]) torch.Size([89, 89])
# torch.Size([50, 50]) torch.Size([50, 50])
# torch.Size([31, 31]) torch.Size([31, 31])
# torch.Size([16, 16]) torch.Size([16, 16])
# torch.Size([39, 39]) torch.Size([39, 39])
# torch.Size([25, 25]) torch.Size([25, 25])
# torch.Size([53, 53]) torch.Size([53, 53])
# torch.Size([25, 25]) torch.Size([25, 25])
# torch.Size([232, 232]) torch.Size([232, 232])
# torch.Size([59, 59]) torch.Size([59, 59])
# torch.Size([145, 145]) torch.Size([145, 145])
# torch.Size([92, 92]) torch.Size([92, 92])
# torch.Size([67, 67]) torch.Size([67, 67])
# torch.Size([40, 40]) torch.Size([40, 40])
# torch.Size([112, 112]) torch.Size([112, 112])
# torch.Size([27, 27]) torch.Size([27, 27])
# torch.Size([174, 174]) torch.Size([174, 174])
# torch.Size([49, 49]) torch.Size([49, 49])
# torch.Size([61, 61]) torch.Size([61, 61])
# torch.Size([33, 33]) torch.Size([33, 33])
# torch.Size([78, 78]) torch.Size([78, 78])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([310, 310]) torch.Size([310, 310])
# torch.Size([72, 72]) torch.Size([72, 72])
# torch.Size([233, 233]) torch.Size([233, 233])
# torch.Size([45, 45]) torch.Size([45, 45])
# torch.Size([80, 80]) torch.Size([80, 80])
# torch.Size([10, 10]) torch.Size([10, 10])
# torch.Size([86, 86]) torch.Size([86, 86])
# torch.Size([48, 48]) torch.Size([48, 48])
# torch.Size([167, 167]) torch.Size([167, 167])
# torch.Size([52, 52]) torch.Size([52, 52])
# torch.Size([59, 59]) torch.Size([59, 59])
# torch.Size([29, 29]) torch.Size([29, 29])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([150, 150]) torch.Size([150, 150])
# torch.Size([48, 48]) torch.Size([48, 48])
# torch.Size([28, 28]) torch.Size([28, 28])
# torch.Size([15, 15]) torch.Size([15, 15])
# torch.Size([48, 48]) torch.Size([48, 48])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([42, 42]) torch.Size([42, 42])
# torch.Size([23, 23]) torch.Size([23, 23])
# torch.Size([153, 153]) torch.Size([153, 153])
# torch.Size([54, 54]) torch.Size([54, 54])
# torch.Size([43, 43]) torch.Size([43, 43])
# torch.Size([23, 23]) torch.Size([23, 23])
# torch.Size([44, 44]) torch.Size([44, 44])
# torch.Size([14, 14]) torch.Size([14, 14])
# torch.Size([126, 126]) torch.Size([126, 126])
# torch.Size([8, 8]) torch.Size([8, 8])
# torch.Size([33, 33]) torch.Size([33, 33])
# torch.Size([22, 22]) torch.Size([22, 22])
# torch.Size([69, 69]) torch.Size([69, 69])
# torch.Size([30, 30]) torch.Size([30, 30])
# torch.Size([263, 263]) torch.Size([263, 263])
# torch.Size([51, 51]) torch.Size([51, 51])
# torch.Size([82, 82]) torch.Size([82, 82])
# torch.Size([43, 43]) torch.Size([43, 43])
# torch.Size([483, 483]) torch.Size([483, 483])
# torch.Size([128, 128]) torch.Size([128, 128])
# torch.Size([255, 255]) torch.Size([255, 255])
# torch.Size([97, 97]) torch.Size([97, 97])
# torch.Size([77, 77]) torch.Size([77, 77])
# torch.Size([47, 47]) torch.Size([47, 47])
# torch.Size([120, 120]) torch.Size([120, 120])
# torch.Size([19, 19]) torch.Size([19, 19])
# torch.Size([149, 149]) torch.Size([149, 149])
# torch.Size([49, 49]) torch.Size([49, 49])
# torch.Size([123, 123]) torch.Size([123, 123])
# torch.Size([43, 43]) torch.Size([43, 43])
# torch.Size([151, 151]) torch.Size([151, 151])
# torch.Size([58, 58]) torch.Size([58, 58])
# torch.Size([66, 66]) torch.Size([66, 66])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([27, 27]) torch.Size([27, 27])
# torch.Size([15, 15]) torch.Size([15, 15])
# torch.Size([157, 157]) torch.Size([157, 157])
# torch.Size([43, 43]) torch.Size([43, 43])
# torch.Size([53, 53]) torch.Size([53, 53])
# torch.Size([30, 30]) torch.Size([30, 30])
# torch.Size([392, 392]) torch.Size([392, 392])
# torch.Size([220, 220]) torch.Size([220, 220])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([16, 16]) torch.Size([16, 16])
# torch.Size([68, 68]) torch.Size([68, 68])
# torch.Size([39, 39]) torch.Size([39, 39])
# torch.Size([117, 117]) torch.Size([117, 117])
# torch.Size([58, 58]) torch.Size([58, 58])
# torch.Size([117, 117]) torch.Size([117, 117])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([65, 65]) torch.Size([65, 65])
# torch.Size([36, 36]) torch.Size([36, 36])
# torch.Size([24, 24]) torch.Size([24, 24])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([227, 227]) torch.Size([227, 227])
# torch.Size([36, 36]) torch.Size([36, 36])
# torch.Size([115, 115]) torch.Size([115, 115])
# torch.Size([74, 74]) torch.Size([74, 74])
# torch.Size([316, 316]) torch.Size([316, 316])
# torch.Size([108, 108]) torch.Size([108, 108])
# torch.Size([108, 108]) torch.Size([108, 108])
# torch.Size([57, 57]) torch.Size([57, 57])
# torch.Size([137, 137]) torch.Size([137, 137])
# torch.Size([17, 17]) torch.Size([17, 17])
# torch.Size([110, 110]) torch.Size([110, 110])
# torch.Size([57, 57]) torch.Size([57, 57])
# torch.Size([25, 25]) torch.Size([25, 25])
# torch.Size([16, 16]) torch.Size([16, 16])
# torch.Size([24, 24]) torch.Size([24, 24])
# torch.Size([15, 15]) torch.Size([15, 15])
# torch.Size([28, 28]) torch.Size([28, 28])
# torch.Size([19, 19]) torch.Size([19, 19])
# torch.Size([77, 77]) torch.Size([77, 77])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([87, 87]) torch.Size([87, 87])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([135, 135]) torch.Size([135, 135])
# torch.Size([50, 50]) torch.Size([50, 50])
# torch.Size([165, 165]) torch.Size([165, 165])
# torch.Size([48, 48]) torch.Size([48, 48])
# torch.Size([121, 121]) torch.Size([121, 121])
# torch.Size([29, 29]) torch.Size([29, 29])
# torch.Size([37, 37]) torch.Size([37, 37])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([83, 83]) torch.Size([83, 83])
# torch.Size([52, 52]) torch.Size([52, 52])
# torch.Size([76, 76]) torch.Size([76, 76])
# torch.Size([30, 30]) torch.Size([30, 30])
# torch.Size([53, 53]) torch.Size([53, 53])
# torch.Size([27, 27]) torch.Size([27, 27])
# torch.Size([64, 64]) torch.Size([64, 64])
# torch.Size([33, 33]) torch.Size([33, 33])
# torch.Size([115, 115]) torch.Size([115, 115])
# torch.Size([62, 62]) torch.Size([62, 62])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([64, 64]) torch.Size([64, 64])
# torch.Size([43, 43]) torch.Size([43, 43])
# torch.Size([85, 85]) torch.Size([85, 85])
# torch.Size([44, 44]) torch.Size([44, 44])
# torch.Size([39, 39]) torch.Size([39, 39])
# torch.Size([20, 20]) torch.Size([20, 20])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([12, 12]) torch.Size([12, 12])
# torch.Size([87, 87]) torch.Size([87, 87])
# torch.Size([51, 51]) torch.Size([51, 51])
# torch.Size([114, 114]) torch.Size([114, 114])
# torch.Size([29, 29]) torch.Size([29, 29])
# torch.Size([156, 156]) torch.Size([156, 156])
# torch.Size([103, 103]) torch.Size([103, 103])
# torch.Size([47, 47]) torch.Size([47, 47])
# torch.Size([23, 23]) torch.Size([23, 23])
# torch.Size([80, 80]) torch.Size([80, 80])
# torch.Size([39, 39]) torch.Size([39, 39])
# torch.Size([232, 232]) torch.Size([232, 232])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([50, 50]) torch.Size([50, 50])
# torch.Size([8, 8]) torch.Size([8, 8])
# torch.Size([37, 37]) torch.Size([37, 37])
# torch.Size([20, 20]) torch.Size([20, 20])
# torch.Size([80, 80]) torch.Size([80, 80])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([64, 64]) torch.Size([64, 64])
# torch.Size([12, 12]) torch.Size([12, 12])
# torch.Size([501, 501]) torch.Size([501, 501])
# torch.Size([125, 125]) torch.Size([125, 125])
# torch.Size([150, 150]) torch.Size([150, 150])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([90, 90]) torch.Size([90, 90])
# torch.Size([35, 35]) torch.Size([35, 35])
# torch.Size([255, 255]) torch.Size([255, 255])
# torch.Size([160, 160]) torch.Size([160, 160])
# torch.Size([43, 43]) torch.Size([43, 43])
# torch.Size([27, 27]) torch.Size([27, 27])
# torch.Size([89, 89]) torch.Size([89, 89])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([90, 90]) torch.Size([90, 90])
# torch.Size([51, 51]) torch.Size([51, 51])
# torch.Size([164, 164]) torch.Size([164, 164])
# torch.Size([23, 23]) torch.Size([23, 23])
# torch.Size([60, 60]) torch.Size([60, 60])
# torch.Size([31, 31]) torch.Size([31, 31])
# torch.Size([66, 66]) torch.Size([66, 66])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([82, 82]) torch.Size([82, 82])
# torch.Size([48, 48]) torch.Size([48, 48])
# torch.Size([72, 72]) torch.Size([72, 72])
# torch.Size([34, 34]) torch.Size([34, 34])
# torch.Size([894, 894]) torch.Size([894, 894])
# torch.Size([130, 130]) torch.Size([130, 130])
# torch.Size([66, 66]) torch.Size([66, 66])
# torch.Size([36, 36]) torch.Size([36, 36])
# torch.Size([71, 71]) torch.Size([71, 71])
# torch.Size([34, 34]) torch.Size([34, 34])
# torch.Size([47, 47]) torch.Size([47, 47])
# torch.Size([25, 25]) torch.Size([25, 25])
# torch.Size([69, 69]) torch.Size([69, 69])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([110, 110]) torch.Size([110, 110])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([59, 59]) torch.Size([59, 59])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([20, 20]) torch.Size([20, 20])
# torch.Size([12, 12]) torch.Size([12, 12])
# torch.Size([212, 212]) torch.Size([212, 212])
# torch.Size([31, 31]) torch.Size([31, 31])
# torch.Size([61, 61]) torch.Size([61, 61])
# torch.Size([41, 41]) torch.Size([41, 41])
# torch.Size([116, 116]) torch.Size([116, 116])
# torch.Size([63, 63]) torch.Size([63, 63])
# torch.Size([44, 44]) torch.Size([44, 44])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([66, 66]) torch.Size([66, 66])
# torch.Size([25, 25]) torch.Size([25, 25])
# torch.Size([70, 70]) torch.Size([70, 70])
# torch.Size([39, 39]) torch.Size([39, 39])
# torch.Size([144, 144]) torch.Size([144, 144])
# torch.Size([48, 48]) torch.Size([48, 48])
# torch.Size([51, 51]) torch.Size([51, 51])
# torch.Size([31, 31]) torch.Size([31, 31])
# torch.Size([96, 96]) torch.Size([96, 96])
# torch.Size([29, 29]) torch.Size([29, 29])
# torch.Size([450, 450]) torch.Size([450, 450])
# torch.Size([130, 130]) torch.Size([130, 130])
# torch.Size([72, 72]) torch.Size([72, 72])
# torch.Size([43, 43]) torch.Size([43, 43])
# torch.Size([111, 111]) torch.Size([111, 111])
# torch.Size([74, 74]) torch.Size([74, 74])
# torch.Size([58, 58]) torch.Size([58, 58])
# torch.Size([34, 34]) torch.Size([34, 34])
# torch.Size([71, 71]) torch.Size([71, 71])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([80, 80]) torch.Size([80, 80])
# torch.Size([45, 45]) torch.Size([45, 45])
# torch.Size([156, 156]) torch.Size([156, 156])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([57, 57]) torch.Size([57, 57])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([63, 63]) torch.Size([63, 63])
# torch.Size([31, 31]) torch.Size([31, 31])
# torch.Size([70, 70]) torch.Size([70, 70])
# torch.Size([17, 17]) torch.Size([17, 17])
# torch.Size([69, 69]) torch.Size([69, 69])
# torch.Size([35, 35]) torch.Size([35, 35])
# torch.Size([71, 71]) torch.Size([71, 71])
# torch.Size([39, 39]) torch.Size([39, 39])
# torch.Size([178, 178]) torch.Size([178, 178])
# torch.Size([37, 37]) torch.Size([37, 37])
# torch.Size([68, 68]) torch.Size([68, 68])
# torch.Size([46, 46]) torch.Size([46, 46])
# torch.Size([316, 316]) torch.Size([316, 316])
# torch.Size([19, 19]) torch.Size([19, 19])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([15, 15]) torch.Size([15, 15])
# torch.Size([153, 153]) torch.Size([153, 153])
# torch.Size([52, 52]) torch.Size([52, 52])
# torch.Size([42, 42]) torch.Size([42, 42])
# torch.Size([25, 25]) torch.Size([25, 25])
# torch.Size([64, 64]) torch.Size([64, 64])
# torch.Size([40, 40]) torch.Size([40, 40])
# torch.Size([93, 93]) torch.Size([93, 93])
# torch.Size([49, 49]) torch.Size([49, 49])
# torch.Size([435, 435]) torch.Size([435, 435])
# torch.Size([66, 66]) torch.Size([66, 66])
# torch.Size([57, 57]) torch.Size([57, 57])
# torch.Size([33, 33]) torch.Size([33, 33])
# torch.Size([194, 194]) torch.Size([194, 194])
# torch.Size([22, 22]) torch.Size([22, 22])
# torch.Size([131, 131]) torch.Size([131, 131])
# torch.Size([33, 33]) torch.Size([33, 33])
# torch.Size([79, 79]) torch.Size([79, 79])
# torch.Size([15, 15]) torch.Size([15, 15])
# torch.Size([93, 93]) torch.Size([93, 93])
# torch.Size([56, 56]) torch.Size([56, 56])
# torch.Size([199, 199]) torch.Size([199, 199])
# torch.Size([106, 106]) torch.Size([106, 106])
# torch.Size([65, 65]) torch.Size([65, 65])
# torch.Size([19, 19]) torch.Size([19, 19])
# torch.Size([31, 31]) torch.Size([31, 31])
# torch.Size([19, 19]) torch.Size([19, 19])
# torch.Size([37, 37]) torch.Size([37, 37])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([93, 93]) torch.Size([93, 93])
# torch.Size([42, 42]) torch.Size([42, 42])
# torch.Size([198, 198]) torch.Size([198, 198])
# torch.Size([28, 28]) torch.Size([28, 28])
# torch.Size([55, 55]) torch.Size([55, 55])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([114, 114]) torch.Size([114, 114])
# torch.Size([57, 57]) torch.Size([57, 57])
# torch.Size([193, 193]) torch.Size([193, 193])
# torch.Size([58, 58]) torch.Size([58, 58])
# torch.Size([69, 69]) torch.Size([69, 69])
# torch.Size([24, 24]) torch.Size([24, 24])
# torch.Size([67, 67]) torch.Size([67, 67])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([62, 62]) torch.Size([62, 62])
# torch.Size([35, 35]) torch.Size([35, 35])
# torch.Size([90, 90]) torch.Size([90, 90])
# torch.Size([31, 31]) torch.Size([31, 31])
# torch.Size([166, 166]) torch.Size([166, 166])
# torch.Size([34, 34]) torch.Size([34, 34])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([128, 128]) torch.Size([128, 128])
# torch.Size([64, 64]) torch.Size([64, 64])
# torch.Size([48, 48]) torch.Size([48, 48])
# torch.Size([29, 29]) torch.Size([29, 29])
# torch.Size([118, 118]) torch.Size([118, 118])
# torch.Size([14, 14]) torch.Size([14, 14])
# torch.Size([125, 125]) torch.Size([125, 125])
# torch.Size([55, 55]) torch.Size([55, 55])
# torch.Size([142, 142]) torch.Size([142, 142])
# torch.Size([25, 25]) torch.Size([25, 25])
# torch.Size([66, 66]) torch.Size([66, 66])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([541, 541]) torch.Size([541, 541])
# torch.Size([127, 127]) torch.Size([127, 127])
# torch.Size([245, 245]) torch.Size([245, 245])
# torch.Size([25, 25]) torch.Size([25, 25])
# torch.Size([54, 54]) torch.Size([54, 54])
# torch.Size([31, 31]) torch.Size([31, 31])
# torch.Size([48, 48]) torch.Size([48, 48])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([22, 22]) torch.Size([22, 22])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([20, 20]) torch.Size([20, 20])
# torch.Size([314, 314]) torch.Size([314, 314])
# torch.Size([83, 83]) torch.Size([83, 83])
# torch.Size([20, 20]) torch.Size([20, 20])
# torch.Size([12, 12]) torch.Size([12, 12])
# torch.Size([42, 42]) torch.Size([42, 42])
# torch.Size([20, 20]) torch.Size([20, 20])
# torch.Size([61, 61]) torch.Size([61, 61])
# torch.Size([33, 33]) torch.Size([33, 33])
# torch.Size([51, 51]) torch.Size([51, 51])
# torch.Size([31, 31]) torch.Size([31, 31])
# torch.Size([144, 144]) torch.Size([144, 144])
# torch.Size([34, 34]) torch.Size([34, 34])
# torch.Size([82, 82]) torch.Size([82, 82])
# torch.Size([49, 49]) torch.Size([49, 49])
# torch.Size([183, 183]) torch.Size([183, 183])
# torch.Size([41, 41]) torch.Size([41, 41])
# torch.Size([20, 20]) torch.Size([20, 20])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([46, 46]) torch.Size([46, 46])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([63, 63]) torch.Size([63, 63])
# torch.Size([10, 10]) torch.Size([10, 10])
# torch.Size([102, 102]) torch.Size([102, 102])
# torch.Size([36, 36]) torch.Size([36, 36])
# torch.Size([59, 59]) torch.Size([59, 59])
# torch.Size([17, 17]) torch.Size([17, 17])
# torch.Size([125, 125]) torch.Size([125, 125])
# torch.Size([29, 29]) torch.Size([29, 29])
# torch.Size([148, 148]) torch.Size([148, 148])
# torch.Size([80, 80]) torch.Size([80, 80])
# torch.Size([37, 37]) torch.Size([37, 37])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([56, 56]) torch.Size([56, 56])
# torch.Size([15, 15]) torch.Size([15, 15])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([24, 24]) torch.Size([24, 24])
# torch.Size([49, 49]) torch.Size([49, 49])
# torch.Size([27, 27]) torch.Size([27, 27])
# torch.Size([48, 48]) torch.Size([48, 48])
# torch.Size([30, 30]) torch.Size([30, 30])
# torch.Size([27, 27]) torch.Size([27, 27])
# torch.Size([17, 17]) torch.Size([17, 17])
# torch.Size([43, 43]) torch.Size([43, 43])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([97, 97]) torch.Size([97, 97])
# torch.Size([29, 29]) torch.Size([29, 29])
# torch.Size([98, 98]) torch.Size([98, 98])
# torch.Size([24, 24]) torch.Size([24, 24])
# torch.Size([69, 69]) torch.Size([69, 69])
# torch.Size([41, 41]) torch.Size([41, 41])
# torch.Size([141, 141]) torch.Size([141, 141])
# torch.Size([84, 84]) torch.Size([84, 84])
# torch.Size([210, 210]) torch.Size([210, 210])
# torch.Size([121, 121]) torch.Size([121, 121])
# torch.Size([36, 36]) torch.Size([36, 36])
# torch.Size([25, 25]) torch.Size([25, 25])
# torch.Size([36, 36]) torch.Size([36, 36])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([123, 123]) torch.Size([123, 123])
# torch.Size([42, 42]) torch.Size([42, 42])
# torch.Size([39, 39]) torch.Size([39, 39])
# torch.Size([22, 22]) torch.Size([22, 22])
# torch.Size([24, 24]) torch.Size([24, 24])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([27, 27]) torch.Size([27, 27])
# torch.Size([16, 16]) torch.Size([16, 16])
# torch.Size([121, 121]) torch.Size([121, 121])
# torch.Size([67, 67]) torch.Size([67, 67])
# torch.Size([89, 89]) torch.Size([89, 89])
# torch.Size([6, 6]) torch.Size([6, 6])
# torch.Size([39, 39]) torch.Size([39, 39])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([86, 86]) torch.Size([86, 86])
# torch.Size([35, 35]) torch.Size([35, 35])
# torch.Size([53, 53]) torch.Size([53, 53])
# torch.Size([28, 28]) torch.Size([28, 28])
# torch.Size([89, 89]) torch.Size([89, 89])
# torch.Size([48, 48]) torch.Size([48, 48])
# torch.Size([41, 41]) torch.Size([41, 41])
# torch.Size([16, 16]) torch.Size([16, 16])
# torch.Size([57, 57]) torch.Size([57, 57])
# torch.Size([36, 36]) torch.Size([36, 36])
# torch.Size([75, 75]) torch.Size([75, 75])
# torch.Size([14, 14]) torch.Size([14, 14])
# torch.Size([23, 23]) torch.Size([23, 23])
# torch.Size([15, 15]) torch.Size([15, 15])
# torch.Size([61, 61]) torch.Size([61, 61])
# torch.Size([34, 34]) torch.Size([34, 34])
# torch.Size([88, 88]) torch.Size([88, 88])
# torch.Size([54, 54]) torch.Size([54, 54])
# torch.Size([52, 52]) torch.Size([52, 52])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([168, 168]) torch.Size([168, 168])
# torch.Size([16, 16]) torch.Size([16, 16])
# torch.Size([91, 91]) torch.Size([91, 91])
# torch.Size([46, 46]) torch.Size([46, 46])
# torch.Size([47, 47]) torch.Size([47, 47])
# torch.Size([25, 25]) torch.Size([25, 25])
# torch.Size([45, 45]) torch.Size([45, 45])
# torch.Size([23, 23]) torch.Size([23, 23])
# torch.Size([16, 16]) torch.Size([16, 16])
# torch.Size([12, 12]) torch.Size([12, 12])
# torch.Size([40, 40]) torch.Size([40, 40])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([49, 49]) torch.Size([49, 49])
# torch.Size([28, 28]) torch.Size([28, 28])
# torch.Size([57, 57]) torch.Size([57, 57])
# torch.Size([30, 30]) torch.Size([30, 30])
# torch.Size([74, 74]) torch.Size([74, 74])
# torch.Size([2, 2]) torch.Size([2, 2])
# torch.Size([99, 99]) torch.Size([99, 99])
# torch.Size([29, 29]) torch.Size([29, 29])
# torch.Size([25, 25]) torch.Size([25, 25])
# torch.Size([14, 14]) torch.Size([14, 14])
# torch.Size([52, 52]) torch.Size([52, 52])
# torch.Size([25, 25]) torch.Size([25, 25])
# torch.Size([214, 214]) torch.Size([214, 214])
# torch.Size([33, 33]) torch.Size([33, 33])
# torch.Size([60, 60]) torch.Size([60, 60])
# torch.Size([39, 39]) torch.Size([39, 39])
# torch.Size([80, 80]) torch.Size([80, 80])
# torch.Size([45, 45]) torch.Size([45, 45])
# torch.Size([171, 171]) torch.Size([171, 171])
# torch.Size([67, 67]) torch.Size([67, 67])
# torch.Size([78, 78]) torch.Size([78, 78])
# torch.Size([48, 48]) torch.Size([48, 48])
# torch.Size([86, 86]) torch.Size([86, 86])
# torch.Size([50, 50]) torch.Size([50, 50])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([8, 8]) torch.Size([8, 8])
# torch.Size([138, 138]) torch.Size([138, 138])
# torch.Size([43, 43]) torch.Size([43, 43])
# torch.Size([42, 42]) torch.Size([42, 42])
# torch.Size([25, 25]) torch.Size([25, 25])
# torch.Size([64, 64]) torch.Size([64, 64])
# torch.Size([31, 31]) torch.Size([31, 31])
# torch.Size([58, 58]) torch.Size([58, 58])
# torch.Size([29, 29]) torch.Size([29, 29])
# torch.Size([59, 59]) torch.Size([59, 59])
# torch.Size([33, 33]) torch.Size([33, 33])
# torch.Size([160, 160]) torch.Size([160, 160])
# torch.Size([81, 81]) torch.Size([81, 81])
# torch.Size([45, 45]) torch.Size([45, 45])
# torch.Size([29, 29]) torch.Size([29, 29])
# torch.Size([43, 43]) torch.Size([43, 43])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([43, 43]) torch.Size([43, 43])
# torch.Size([24, 24]) torch.Size([24, 24])
# torch.Size([47, 47]) torch.Size([47, 47])
# torch.Size([29, 29]) torch.Size([29, 29])
# torch.Size([61, 61]) torch.Size([61, 61])
# torch.Size([24, 24]) torch.Size([24, 24])
# torch.Size([65, 65]) torch.Size([65, 65])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([54, 54]) torch.Size([54, 54])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([39, 39]) torch.Size([39, 39])
# torch.Size([24, 24]) torch.Size([24, 24])
# torch.Size([36, 36]) torch.Size([36, 36])
# torch.Size([19, 19]) torch.Size([19, 19])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([123, 123]) torch.Size([123, 123])
# torch.Size([23, 23]) torch.Size([23, 23])
# torch.Size([153, 153]) torch.Size([153, 153])
# torch.Size([87, 87]) torch.Size([87, 87])
# torch.Size([142, 142]) torch.Size([142, 142])
# torch.Size([42, 42]) torch.Size([42, 42])
# torch.Size([57, 57]) torch.Size([57, 57])
# torch.Size([28, 28]) torch.Size([28, 28])
# torch.Size([65, 65]) torch.Size([65, 65])
# torch.Size([34, 34]) torch.Size([34, 34])
# torch.Size([52, 52]) torch.Size([52, 52])
# torch.Size([27, 27]) torch.Size([27, 27])
# torch.Size([89, 89]) torch.Size([89, 89])
# torch.Size([28, 28]) torch.Size([28, 28])
# torch.Size([214, 214]) torch.Size([214, 214])
# torch.Size([46, 46]) torch.Size([46, 46])
# torch.Size([84, 84]) torch.Size([84, 84])
# torch.Size([30, 30]) torch.Size([30, 30])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([67, 67]) torch.Size([67, 67])
# torch.Size([15, 15]) torch.Size([15, 15])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([72, 72]) torch.Size([72, 72])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([52, 52]) torch.Size([52, 52])
# torch.Size([23, 23]) torch.Size([23, 23])
# torch.Size([15, 15]) torch.Size([15, 15])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([42, 42]) torch.Size([42, 42])
# torch.Size([22, 22]) torch.Size([22, 22])
# torch.Size([39, 39]) torch.Size([39, 39])
# torch.Size([19, 19]) torch.Size([19, 19])
# torch.Size([39, 39]) torch.Size([39, 39])
# torch.Size([23, 23]) torch.Size([23, 23])
# torch.Size([17, 17]) torch.Size([17, 17])
# torch.Size([12, 12]) torch.Size([12, 12])
# torch.Size([20, 20]) torch.Size([20, 20])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([86, 86]) torch.Size([86, 86])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([71, 71]) torch.Size([71, 71])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([186, 186]) torch.Size([186, 186])
# torch.Size([101, 101]) torch.Size([101, 101])
# torch.Size([42, 42]) torch.Size([42, 42])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([118, 118]) torch.Size([118, 118])
# torch.Size([16, 16]) torch.Size([16, 16])
# torch.Size([45, 45]) torch.Size([45, 45])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([100, 100]) torch.Size([100, 100])
# torch.Size([46, 46]) torch.Size([46, 46])
# torch.Size([27, 27]) torch.Size([27, 27])
# torch.Size([15, 15]) torch.Size([15, 15])
# torch.Size([30, 30]) torch.Size([30, 30])
# torch.Size([15, 15]) torch.Size([15, 15])
# torch.Size([107, 107]) torch.Size([107, 107])
# torch.Size([12, 12]) torch.Size([12, 12])
# torch.Size([202, 202]) torch.Size([202, 202])
# torch.Size([65, 65]) torch.Size([65, 65])
# torch.Size([69, 69]) torch.Size([69, 69])
# torch.Size([37, 37]) torch.Size([37, 37])
# torch.Size([66, 66]) torch.Size([66, 66])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([174, 174]) torch.Size([174, 174])
# torch.Size([29, 29]) torch.Size([29, 29])
# torch.Size([194, 194]) torch.Size([194, 194])
# torch.Size([55, 55]) torch.Size([55, 55])
# torch.Size([64, 64]) torch.Size([64, 64])
# torch.Size([29, 29]) torch.Size([29, 29])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([22, 22]) torch.Size([22, 22])
# torch.Size([91, 91]) torch.Size([91, 91])
# torch.Size([33, 33]) torch.Size([33, 33])
# torch.Size([45, 45]) torch.Size([45, 45])
# torch.Size([22, 22]) torch.Size([22, 22])
# torch.Size([183, 183]) torch.Size([183, 183])
# torch.Size([22, 22]) torch.Size([22, 22])
# torch.Size([180, 180]) torch.Size([180, 180])
# torch.Size([43, 43]) torch.Size([43, 43])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([16, 16]) torch.Size([16, 16])
# torch.Size([93, 93]) torch.Size([93, 93])
# torch.Size([30, 30]) torch.Size([30, 30])
# torch.Size([91, 91]) torch.Size([91, 91])
# torch.Size([37, 37]) torch.Size([37, 37])
# torch.Size([20, 20]) torch.Size([20, 20])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([34, 34]) torch.Size([34, 34])
# torch.Size([19, 19]) torch.Size([19, 19])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([17, 17]) torch.Size([17, 17])
# torch.Size([10, 10]) torch.Size([10, 10])
# torch.Size([64, 64]) torch.Size([64, 64])
# torch.Size([36, 36]) torch.Size([36, 36])
# torch.Size([39, 39]) torch.Size([39, 39])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([19, 19]) torch.Size([19, 19])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([6, 6]) torch.Size([6, 6])
# torch.Size([4, 4]) torch.Size([4, 4])
# torch.Size([63, 63]) torch.Size([63, 63])
# torch.Size([34, 34]) torch.Size([34, 34])
# torch.Size([55, 55]) torch.Size([55, 55])
# torch.Size([29, 29]) torch.Size([29, 29])
# torch.Size([58, 58]) torch.Size([58, 58])
# torch.Size([22, 22]) torch.Size([22, 22])
# torch.Size([58, 58]) torch.Size([58, 58])
# torch.Size([28, 28]) torch.Size([28, 28])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([14, 14]) torch.Size([14, 14])
# torch.Size([56, 56]) torch.Size([56, 56])
# torch.Size([30, 30]) torch.Size([30, 30])
# torch.Size([181, 181]) torch.Size([181, 181])
# torch.Size([59, 59]) torch.Size([59, 59])
# torch.Size([50, 50]) torch.Size([50, 50])
# torch.Size([25, 25]) torch.Size([25, 25])
# torch.Size([177, 177]) torch.Size([177, 177])
# torch.Size([56, 56]) torch.Size([56, 56])
# torch.Size([158, 158]) torch.Size([158, 158])
# torch.Size([35, 35]) torch.Size([35, 35])
# torch.Size([76, 76]) torch.Size([76, 76])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([45, 45]) torch.Size([45, 45])
# torch.Size([27, 27]) torch.Size([27, 27])
# torch.Size([148, 148]) torch.Size([148, 148])
# torch.Size([56, 56]) torch.Size([56, 56])
# torch.Size([50, 50]) torch.Size([50, 50])
# torch.Size([31, 31]) torch.Size([31, 31])
# torch.Size([123, 123]) torch.Size([123, 123])
# torch.Size([59, 59]) torch.Size([59, 59])
# torch.Size([142, 142]) torch.Size([142, 142])
# torch.Size([16, 16]) torch.Size([16, 16])
# torch.Size([124, 124]) torch.Size([124, 124])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([79, 79]) torch.Size([79, 79])
# torch.Size([36, 36]) torch.Size([36, 36])
# torch.Size([70, 70]) torch.Size([70, 70])
# torch.Size([45, 45]) torch.Size([45, 45])
# torch.Size([170, 170]) torch.Size([170, 170])
# torch.Size([98, 98]) torch.Size([98, 98])
# torch.Size([66, 66]) torch.Size([66, 66])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([23, 23]) torch.Size([23, 23])
# torch.Size([15, 15]) torch.Size([15, 15])
# torch.Size([35, 35]) torch.Size([35, 35])
# torch.Size([20, 20]) torch.Size([20, 20])
# torch.Size([42, 42]) torch.Size([42, 42])
# torch.Size([22, 22]) torch.Size([22, 22])
# torch.Size([299, 299]) torch.Size([299, 299])
# torch.Size([29, 29]) torch.Size([29, 29])
# torch.Size([120, 120]) torch.Size([120, 120])
# torch.Size([65, 65]) torch.Size([65, 65])
# torch.Size([42, 42]) torch.Size([42, 42])
# torch.Size([23, 23]) torch.Size([23, 23])
# torch.Size([39, 39]) torch.Size([39, 39])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([58, 58]) torch.Size([58, 58])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([234, 234]) torch.Size([234, 234])
# torch.Size([88, 88]) torch.Size([88, 88])
# torch.Size([86, 86]) torch.Size([86, 86])
# torch.Size([50, 50]) torch.Size([50, 50])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([79, 79]) torch.Size([79, 79])
# torch.Size([47, 47]) torch.Size([47, 47])
# torch.Size([104, 104]) torch.Size([104, 104])
# torch.Size([19, 19]) torch.Size([19, 19])
# torch.Size([57, 57]) torch.Size([57, 57])
# torch.Size([24, 24]) torch.Size([24, 24])
# torch.Size([34, 34]) torch.Size([34, 34])
# torch.Size([25, 25]) torch.Size([25, 25])
# torch.Size([104, 104]) torch.Size([104, 104])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([283, 283]) torch.Size([283, 283])
# torch.Size([49, 49]) torch.Size([49, 49])
# torch.Size([162, 162]) torch.Size([162, 162])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([72, 72]) torch.Size([72, 72])
# torch.Size([14, 14]) torch.Size([14, 14])
# torch.Size([283, 283]) torch.Size([283, 283])
# torch.Size([60, 60]) torch.Size([60, 60])
# torch.Size([103, 103]) torch.Size([103, 103])
# torch.Size([36, 36]) torch.Size([36, 36])
# torch.Size([223, 223]) torch.Size([223, 223])
# torch.Size([25, 25]) torch.Size([25, 25])
# torch.Size([51, 51]) torch.Size([51, 51])
# torch.Size([24, 24]) torch.Size([24, 24])
# torch.Size([43, 43]) torch.Size([43, 43])
# torch.Size([24, 24]) torch.Size([24, 24])
# torch.Size([288, 288]) torch.Size([288, 288])
# torch.Size([176, 176]) torch.Size([176, 176])
# torch.Size([51, 51]) torch.Size([51, 51])
# torch.Size([31, 31]) torch.Size([31, 31])
# torch.Size([51, 51]) torch.Size([51, 51])
# torch.Size([31, 31]) torch.Size([31, 31])
# torch.Size([178, 178]) torch.Size([178, 178])
# torch.Size([43, 43]) torch.Size([43, 43])
# torch.Size([75, 75]) torch.Size([75, 75])
# torch.Size([37, 37]) torch.Size([37, 37])
# torch.Size([42, 42]) torch.Size([42, 42])
# torch.Size([22, 22]) torch.Size([22, 22])
# torch.Size([155, 155]) torch.Size([155, 155])
# torch.Size([44, 44]) torch.Size([44, 44])
# torch.Size([50, 50]) torch.Size([50, 50])
# torch.Size([10, 10]) torch.Size([10, 10])
# torch.Size([86, 86]) torch.Size([86, 86])
# torch.Size([16, 16]) torch.Size([16, 16])
# torch.Size([16, 16]) torch.Size([16, 16])
# torch.Size([10, 10]) torch.Size([10, 10])
# torch.Size([39, 39]) torch.Size([39, 39])
# torch.Size([20, 20]) torch.Size([20, 20])
# torch.Size([142, 142]) torch.Size([142, 142])
# torch.Size([81, 81]) torch.Size([81, 81])
# torch.Size([59, 59]) torch.Size([59, 59])
# torch.Size([8, 8]) torch.Size([8, 8])
# torch.Size([123, 123]) torch.Size([123, 123])
# torch.Size([35, 35]) torch.Size([35, 35])
# torch.Size([99, 99]) torch.Size([99, 99])
# torch.Size([19, 19]) torch.Size([19, 19])
# torch.Size([44, 44]) torch.Size([44, 44])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([28, 28]) torch.Size([28, 28])
# torch.Size([17, 17]) torch.Size([17, 17])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([8, 8]) torch.Size([8, 8])
# torch.Size([49, 49]) torch.Size([49, 49])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([61, 61]) torch.Size([61, 61])
# torch.Size([28, 28]) torch.Size([28, 28])
# torch.Size([14, 14]) torch.Size([14, 14])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([53, 53]) torch.Size([53, 53])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([76, 76]) torch.Size([76, 76])
# torch.Size([40, 40]) torch.Size([40, 40])
# torch.Size([68, 68]) torch.Size([68, 68])
# torch.Size([19, 19]) torch.Size([19, 19])
# torch.Size([62, 62]) torch.Size([62, 62])
# torch.Size([19, 19]) torch.Size([19, 19])
# torch.Size([29, 29]) torch.Size([29, 29])
# torch.Size([17, 17]) torch.Size([17, 17])
# torch.Size([92, 92]) torch.Size([92, 92])
# torch.Size([28, 28]) torch.Size([28, 28])
# torch.Size([36, 36]) torch.Size([36, 36])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([75, 75]) torch.Size([75, 75])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([33, 33]) torch.Size([33, 33])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([42, 42]) torch.Size([42, 42])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([28, 28]) torch.Size([28, 28])
# torch.Size([16, 16]) torch.Size([16, 16])
# torch.Size([24, 24]) torch.Size([24, 24])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([86, 86]) torch.Size([86, 86])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([54, 54]) torch.Size([54, 54])
# torch.Size([8, 8]) torch.Size([8, 8])
# torch.Size([104, 104]) torch.Size([104, 104])
# torch.Size([53, 53]) torch.Size([53, 53])
# torch.Size([45, 45]) torch.Size([45, 45])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([44, 44]) torch.Size([44, 44])
# torch.Size([20, 20]) torch.Size([20, 20])
# torch.Size([31, 31]) torch.Size([31, 31])
# torch.Size([16, 16]) torch.Size([16, 16])
# torch.Size([41, 41]) torch.Size([41, 41])
# torch.Size([20, 20]) torch.Size([20, 20])
# torch.Size([183, 183]) torch.Size([183, 183])
# torch.Size([71, 71]) torch.Size([71, 71])
# torch.Size([36, 36]) torch.Size([36, 36])
# torch.Size([20, 20]) torch.Size([20, 20])
# torch.Size([28, 28]) torch.Size([28, 28])
# torch.Size([14, 14]) torch.Size([14, 14])
# torch.Size([33, 33]) torch.Size([33, 33])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([63, 63]) torch.Size([63, 63])
# torch.Size([29, 29]) torch.Size([29, 29])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([8, 8]) torch.Size([8, 8])
# torch.Size([119, 119]) torch.Size([119, 119])
# torch.Size([40, 40]) torch.Size([40, 40])
# torch.Size([60, 60]) torch.Size([60, 60])
# torch.Size([27, 27]) torch.Size([27, 27])
# torch.Size([24, 24]) torch.Size([24, 24])
# torch.Size([14, 14]) torch.Size([14, 14])
# torch.Size([71, 71]) torch.Size([71, 71])
# torch.Size([36, 36]) torch.Size([36, 36])
# torch.Size([20, 20]) torch.Size([20, 20])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([40, 40]) torch.Size([40, 40])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([45, 45]) torch.Size([45, 45])
# torch.Size([22, 22]) torch.Size([22, 22])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([125, 125]) torch.Size([125, 125])
# torch.Size([69, 69]) torch.Size([69, 69])
# torch.Size([97, 97]) torch.Size([97, 97])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([219, 219]) torch.Size([219, 219])
# torch.Size([27, 27]) torch.Size([27, 27])
# torch.Size([44, 44]) torch.Size([44, 44])
# torch.Size([27, 27]) torch.Size([27, 27])
# torch.Size([88, 88]) torch.Size([88, 88])
# torch.Size([57, 57]) torch.Size([57, 57])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([28, 28]) torch.Size([28, 28])
# torch.Size([16, 16]) torch.Size([16, 16])
# torch.Size([62, 62]) torch.Size([62, 62])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([52, 52]) torch.Size([52, 52])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([42, 42]) torch.Size([42, 42])
# torch.Size([7, 7]) torch.Size([7, 7])
# torch.Size([34, 34]) torch.Size([34, 34])
# torch.Size([4, 4]) torch.Size([4, 4])
# torch.Size([34, 34]) torch.Size([34, 34])
# ...
# torch.Size([8, 8]) torch.Size([8, 8])
# torch.Size([25, 25]) torch.Size([25, 25])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([22, 22]) torch.Size([22, 22])
# torch.Size([14, 14]) torch.Size([14, 14])
# torch.Size([86, 86]) torch.Size([86, 86])
# torch.Size([51, 51]) torch.Size([51, 51])
# torch.Size([64, 64]) torch.Size([64, 64])
# torch.Size([42, 42]) torch.Size([42, 42])
# torch.Size([67, 67]) torch.Size([67, 67])
# torch.Size([44, 44]) torch.Size([44, 44])
# torch.Size([15, 15]) torch.Size([15, 15])
# torch.Size([10, 10]) torch.Size([10, 10])
# torch.Size([40, 40]) torch.Size([40, 40])
# torch.Size([17, 17]) torch.Size([17, 17])
# torch.Size([23, 23]) torch.Size([23, 23])
# torch.Size([15, 15]) torch.Size([15, 15])
# torch.Size([14, 14]) torch.Size([14, 14])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([14, 14]) torch.Size([14, 14])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([5, 5]) torch.Size([5, 5])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([17, 17]) torch.Size([17, 17])
# torch.Size([28, 28]) torch.Size([28, 28])
# torch.Size([12, 12]) torch.Size([12, 12])
# torch.Size([62, 62]) torch.Size([62, 62])
# torch.Size([34, 34]) torch.Size([34, 34])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([7, 7]) torch.Size([7, 7])
# torch.Size([129, 129]) torch.Size([129, 129])
# torch.Size([53, 53]) torch.Size([53, 53])
# torch.Size([20, 20]) torch.Size([20, 20])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([31, 31]) torch.Size([31, 31])
# torch.Size([5, 5]) torch.Size([5, 5])
# torch.Size([14, 14]) torch.Size([14, 14])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([15, 15]) torch.Size([15, 15])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([41, 41]) torch.Size([41, 41])
# torch.Size([25, 25]) torch.Size([25, 25])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([63, 63]) torch.Size([63, 63])
# torch.Size([4, 4]) torch.Size([4, 4])
# torch.Size([17, 17]) torch.Size([17, 17])
# torch.Size([10, 10]) torch.Size([10, 10])
# torch.Size([96, 96]) torch.Size([96, 96])
# torch.Size([47, 47]) torch.Size([47, 47])
# torch.Size([126, 126]) torch.Size([126, 126])
# torch.Size([27, 27]) torch.Size([27, 27])
# torch.Size([53, 53]) torch.Size([53, 53])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([15, 15]) torch.Size([15, 15])
# torch.Size([6, 6]) torch.Size([6, 6])
# torch.Size([4, 4]) torch.Size([4, 4])
# torch.Size([15, 15]) torch.Size([15, 15])
# torch.Size([6, 6]) torch.Size([6, 6])
# torch.Size([23, 23]) torch.Size([23, 23])
# torch.Size([6, 6]) torch.Size([6, 6])
# torch.Size([44, 44]) torch.Size([44, 44])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([49, 49]) torch.Size([49, 49])
# torch.Size([25, 25]) torch.Size([25, 25])
# torch.Size([53, 53]) torch.Size([53, 53])
# torch.Size([2, 2]) torch.Size([2, 2])
# torch.Size([16, 16]) torch.Size([16, 16])
# torch.Size([10, 10]) torch.Size([10, 10])
# torch.Size([34, 34]) torch.Size([34, 34])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([12, 12]) torch.Size([12, 12])
# torch.Size([8, 8]) torch.Size([8, 8])
# torch.Size([6, 6]) torch.Size([6, 6])
# torch.Size([4, 4]) torch.Size([4, 4])
# torch.Size([17, 17]) torch.Size([17, 17])
# torch.Size([10, 10]) torch.Size([10, 10])
# torch.Size([25, 25]) torch.Size([25, 25])
# torch.Size([4, 4]) torch.Size([4, 4])
# torch.Size([19, 19]) torch.Size([19, 19])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([47, 47]) torch.Size([47, 47])
# torch.Size([25, 25]) torch.Size([25, 25])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([7, 7]) torch.Size([7, 7])
# torch.Size([28, 28]) torch.Size([28, 28])
# torch.Size([15, 15]) torch.Size([15, 15])
# torch.Size([70, 70]) torch.Size([70, 70])
# torch.Size([40, 40]) torch.Size([40, 40])
# torch.Size([35, 35]) torch.Size([35, 35])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([40, 40]) torch.Size([40, 40])
# torch.Size([8, 8]) torch.Size([8, 8])
# torch.Size([12, 12]) torch.Size([12, 12])
# torch.Size([10, 10]) torch.Size([10, 10])
# torch.Size([16, 16]) torch.Size([16, 16])
# torch.Size([10, 10]) torch.Size([10, 10])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([17, 17]) torch.Size([17, 17])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([8, 8]) torch.Size([8, 8])
# torch.Size([15, 15]) torch.Size([15, 15])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([19, 19]) torch.Size([19, 19])
# torch.Size([12, 12]) torch.Size([12, 12])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([7, 7]) torch.Size([7, 7])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([8, 8]) torch.Size([8, 8])
# torch.Size([19, 19]) torch.Size([19, 19])
# torch.Size([14, 14]) torch.Size([14, 14])
# torch.Size([69, 69]) torch.Size([69, 69])
# torch.Size([37, 37]) torch.Size([37, 37])
# torch.Size([59, 59]) torch.Size([59, 59])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([30, 30]) torch.Size([30, 30])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([37, 37]) torch.Size([37, 37])
# torch.Size([23, 23]) torch.Size([23, 23])
# torch.Size([6, 6]) torch.Size([6, 6])
# torch.Size([4, 4]) torch.Size([4, 4])
# torch.Size([34, 34]) torch.Size([34, 34])
# torch.Size([27, 27]) torch.Size([27, 27])
# torch.Size([146, 146]) torch.Size([146, 146])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([34, 34]) torch.Size([34, 34])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([106, 106]) torch.Size([106, 106])
# torch.Size([12, 12]) torch.Size([12, 12])
# torch.Size([59, 59]) torch.Size([59, 59])
# torch.Size([4, 4]) torch.Size([4, 4])
# torch.Size([34, 34]) torch.Size([34, 34])
# torch.Size([3, 3]) torch.Size([3, 3])
# torch.Size([94, 94]) torch.Size([94, 94])
# torch.Size([48, 48]) torch.Size([48, 48])
# torch.Size([47, 47]) torch.Size([47, 47])
# torch.Size([29, 29]) torch.Size([29, 29])
# torch.Size([20, 20]) torch.Size([20, 20])
# torch.Size([10, 10]) torch.Size([10, 10])
# torch.Size([60, 60]) torch.Size([60, 60])
# torch.Size([0, 0]) torch.Size([0, 0])
# torch.Size([29, 29]) torch.Size([29, 29])
# torch.Size([19, 19]) torch.Size([19, 19])
# torch.Size([16, 16]) torch.Size([16, 16])
# torch.Size([10, 10]) torch.Size([10, 10])
# torch.Size([34, 34]) torch.Size([34, 34])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([17, 17]) torch.Size([17, 17])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([12, 12]) torch.Size([12, 12])
# torch.Size([27, 27]) torch.Size([27, 27])
# torch.Size([16, 16]) torch.Size([16, 16])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([7, 7]) torch.Size([7, 7])
# torch.Size([48, 48]) torch.Size([48, 48])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([7, 7]) torch.Size([7, 7])
# torch.Size([87, 87]) torch.Size([87, 87])
# torch.Size([49, 49]) torch.Size([49, 49])
# torch.Size([46, 46]) torch.Size([46, 46])
# torch.Size([24, 24]) torch.Size([24, 24])
# torch.Size([113, 113]) torch.Size([113, 113])
# torch.Size([63, 63]) torch.Size([63, 63])
# torch.Size([105, 105]) torch.Size([105, 105])
# torch.Size([58, 58]) torch.Size([58, 58])
# torch.Size([24, 24]) torch.Size([24, 24])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([94, 94]) torch.Size([94, 94])
# torch.Size([8, 8]) torch.Size([8, 8])
# torch.Size([30, 30]) torch.Size([30, 30])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([51, 51]) torch.Size([51, 51])
# torch.Size([31, 31]) torch.Size([31, 31])
# torch.Size([86, 86]) torch.Size([86, 86])
# torch.Size([60, 60]) torch.Size([60, 60])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([7, 7]) torch.Size([7, 7])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([8, 8]) torch.Size([8, 8])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([8, 8]) torch.Size([8, 8])
# torch.Size([41, 41]) torch.Size([41, 41])
# torch.Size([23, 23]) torch.Size([23, 23])
# torch.Size([53, 53]) torch.Size([53, 53])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([163, 163]) torch.Size([163, 163])
# torch.Size([97, 97]) torch.Size([97, 97])
# torch.Size([66, 66]) torch.Size([66, 66])
# torch.Size([8, 8]) torch.Size([8, 8])
# torch.Size([19, 19]) torch.Size([19, 19])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([87, 87]) torch.Size([87, 87])
# torch.Size([22, 22]) torch.Size([22, 22])
# torch.Size([22, 22]) torch.Size([22, 22])
# torch.Size([12, 12]) torch.Size([12, 12])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([7, 7]) torch.Size([7, 7])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([139, 139]) torch.Size([139, 139])
# torch.Size([1, 1]) torch.Size([1, 1])
# torch.Size([17, 17]) torch.Size([17, 17])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([40, 40]) torch.Size([40, 40])
# torch.Size([8, 8]) torch.Size([8, 8])
# torch.Size([60, 60]) torch.Size([60, 60])
# torch.Size([4, 4]) torch.Size([4, 4])
# torch.Size([59, 59]) torch.Size([59, 59])
# torch.Size([16, 16]) torch.Size([16, 16])
# torch.Size([27, 27]) torch.Size([27, 27])
# torch.Size([17, 17]) torch.Size([17, 17])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([36, 36]) torch.Size([36, 36])
# torch.Size([17, 17]) torch.Size([17, 17])
# torch.Size([37, 37]) torch.Size([37, 37])
# torch.Size([14, 14]) torch.Size([14, 14])
# torch.Size([22, 22]) torch.Size([22, 22])
# torch.Size([16, 16]) torch.Size([16, 16])
# torch.Size([63, 63]) torch.Size([63, 63])
# torch.Size([16, 16]) torch.Size([16, 16])
# torch.Size([76, 76]) torch.Size([76, 76])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([42, 42]) torch.Size([42, 42])
# torch.Size([8, 8]) torch.Size([8, 8])
# torch.Size([52, 52]) torch.Size([52, 52])
# torch.Size([22, 22]) torch.Size([22, 22])
# torch.Size([65, 65]) torch.Size([65, 65])
# torch.Size([36, 36]) torch.Size([36, 36])
# torch.Size([43, 43]) torch.Size([43, 43])
# torch.Size([24, 24]) torch.Size([24, 24])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([7, 7]) torch.Size([7, 7])
# torch.Size([6, 6]) torch.Size([6, 6])
# torch.Size([4, 4]) torch.Size([4, 4])
# torch.Size([15, 15]) torch.Size([15, 15])
# torch.Size([10, 10]) torch.Size([10, 10])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([6, 6]) torch.Size([6, 6])
# torch.Size([4, 4]) torch.Size([4, 4])
# torch.Size([22, 22]) torch.Size([22, 22])
# torch.Size([12, 12]) torch.Size([12, 12])
# torch.Size([6, 6]) torch.Size([6, 6])
# torch.Size([4, 4]) torch.Size([4, 4])
# torch.Size([33, 33]) torch.Size([33, 33])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([14, 14]) torch.Size([14, 14])
# torch.Size([36, 36]) torch.Size([36, 36])
# torch.Size([4, 4]) torch.Size([4, 4])
# torch.Size([22, 22]) torch.Size([22, 22])
# torch.Size([14, 14]) torch.Size([14, 14])
# torch.Size([62, 62]) torch.Size([62, 62])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([23, 23]) torch.Size([23, 23])
# torch.Size([0, 0]) torch.Size([0, 0])
# torch.Size([19, 19]) torch.Size([19, 19])
# torch.Size([1, 1]) torch.Size([1, 1])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([7, 7]) torch.Size([7, 7])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([8, 8]) torch.Size([8, 8])
# torch.Size([17, 17]) torch.Size([17, 17])
# torch.Size([10, 10]) torch.Size([10, 10])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([8, 8]) torch.Size([8, 8])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([8, 8]) torch.Size([8, 8])
# torch.Size([41, 41]) torch.Size([41, 41])
# torch.Size([20, 20]) torch.Size([20, 20])
# torch.Size([41, 41]) torch.Size([41, 41])
# torch.Size([19, 19]) torch.Size([19, 19])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([35, 35]) torch.Size([35, 35])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([20, 20]) torch.Size([20, 20])
# torch.Size([16, 16]) torch.Size([16, 16])
# torch.Size([12, 12]) torch.Size([12, 12])
# torch.Size([86, 86]) torch.Size([86, 86])
# torch.Size([4, 4]) torch.Size([4, 4])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([16, 16]) torch.Size([16, 16])
# torch.Size([16, 16]) torch.Size([16, 16])
# torch.Size([10, 10]) torch.Size([10, 10])
# torch.Size([20, 20]) torch.Size([20, 20])
# torch.Size([12, 12]) torch.Size([12, 12])
# torch.Size([14, 14]) torch.Size([14, 14])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([58, 58]) torch.Size([58, 58])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([12, 12]) torch.Size([12, 12])
# torch.Size([204, 204]) torch.Size([204, 204])
# torch.Size([59, 59]) torch.Size([59, 59])
# torch.Size([28, 28]) torch.Size([28, 28])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([25, 25]) torch.Size([25, 25])
# torch.Size([7, 7]) torch.Size([7, 7])
# torch.Size([109, 109]) torch.Size([109, 109])
# torch.Size([4, 4]) torch.Size([4, 4])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([20, 20]) torch.Size([20, 20])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([8, 8]) torch.Size([8, 8])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([8, 8]) torch.Size([8, 8])
# torch.Size([16, 16]) torch.Size([16, 16])
# torch.Size([12, 12]) torch.Size([12, 12])
# torch.Size([27, 27]) torch.Size([27, 27])
# torch.Size([17, 17]) torch.Size([17, 17])
# torch.Size([12, 12]) torch.Size([12, 12])
# torch.Size([8, 8]) torch.Size([8, 8])
# torch.Size([26, 26]) torch.Size([26, 26])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([50, 50]) torch.Size([50, 50])
# torch.Size([20, 20]) torch.Size([20, 20])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([2, 2]) torch.Size([2, 2])
# torch.Size([47, 47]) torch.Size([47, 47])
# torch.Size([24, 24]) torch.Size([24, 24])
# torch.Size([41, 41]) torch.Size([41, 41])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([24, 24]) torch.Size([24, 24])
# torch.Size([14, 14]) torch.Size([14, 14])
# torch.Size([6, 6]) torch.Size([6, 6])
# torch.Size([4, 4]) torch.Size([4, 4])
# torch.Size([65, 65]) torch.Size([65, 65])
# torch.Size([32, 32]) torch.Size([32, 32])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([22, 22]) torch.Size([22, 22])
# torch.Size([15, 15]) torch.Size([15, 15])
# torch.Size([2, 2]) torch.Size([2, 2])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([22, 22]) torch.Size([22, 22])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([30, 30]) torch.Size([30, 30])
# torch.Size([15, 15]) torch.Size([15, 15])
# torch.Size([24, 24]) torch.Size([24, 24])
# torch.Size([20, 20]) torch.Size([20, 20])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([8, 8]) torch.Size([8, 8])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([14, 14]) torch.Size([14, 14])
# torch.Size([18, 18]) torch.Size([18, 18])
# torch.Size([12, 12]) torch.Size([12, 12])
# torch.Size([50, 50]) torch.Size([50, 50])
# torch.Size([24, 24]) torch.Size([24, 24])
# torch.Size([64, 64]) torch.Size([64, 64])
# torch.Size([12, 12]) torch.Size([12, 12])
# torch.Size([13, 13]) torch.Size([13, 13])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([34, 34]) torch.Size([34, 34])
# torch.Size([20, 20]) torch.Size([20, 20])
# torch.Size([35, 35]) torch.Size([35, 35])
# torch.Size([21, 21]) torch.Size([21, 21])
# torch.Size([6, 6]) torch.Size([6, 6])
# torch.Size([4, 4]) torch.Size([4, 4])
# torch.Size([11, 11]) torch.Size([11, 11])
# torch.Size([8, 8]) torch.Size([8, 8])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([7, 7]) torch.Size([7, 7])
# torch.Size([38, 38]) torch.Size([38, 38])
# torch.Size([19, 19]) torch.Size([19, 19])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([7, 7]) torch.Size([7, 7])
# torch.Size([27, 27]) torch.Size([27, 27])
# torch.Size([16, 16]) torch.Size([16, 16])
# torch.Size([29, 29]) torch.Size([29, 29])
# torch.Size([17, 17]) torch.Size([17, 17])
# torch.Size([9, 9]) torch.Size([9, 9])
# torch.Size([7, 7]) torch.Size([7, 7])
# torch.Size([74, 74]) torch.Size([74, 74])
# torch.Size([44, 44]) torch.Size([44, 44])
# Done!
# Transform parameters are the same, using existing data_dir: ./data/MUTAG/PROTEINS/PROTEINS/clique_lifting_sann_encoding/2384368974

# %%
dataset_train[15][0][dataset_train[15][1].index('y')]
# Out:
# tensor([0])

# %%
dataset_train[0][0][0].shape
# Out:
# torch.Size([42, 42])

# %% [markdown]
# ## 4. Backbone definition <a class="anchor" id="sec4"></a>

# %% [markdown]
# To implement a new model we only need to define the forward method.
#
# With a hypergraph with $n$ nodes and $m$ hyperedges this model simply calculates the hyperedge features as $X_1 = B_1 \cdot X_0$ where $B_1 \in \mathbb{R}^{n \times m}$ is the incidence matrix, where $B_{ij}=1$ if node $i$ belongs to hyperedge $j$ and is 0 otherwise.
#
# Then the outputs are computed as $X^{'}_0=\text{ReLU}(W_0 \cdot X_0 + B_0)$ and $X^{'}_1=\text{ReLU}(W_1 \cdot X_1 + B_1)$, by simply using two linear layers with ReLU activation.

# %% [markdown]
# ## 5. Model initialization <a class="anchor" id="sec5"></a>

# %% [markdown]
# Now that the model is defined we can create the TBXModel, which takes care of implementing everything else that is needed to train the model.
#
# First we need to implement a few classes to specify the behaviour of the model.

# %%
backbone = SANN(dim_1=in_channels, dim_2=hidden_dim_1,dim_3=hidden_dim_2)
backbone_wrapper = wrapper(**wrapper_config)

readout = SANNReadout(**readout_config)
loss = TBXLoss(**loss_config)

in_channels_hops = [
    [in_channels, 6, 18],
    [in_channels, 12, 39],
    [in_channels, 9, 30]
]
feature_encoder = SANNCellEncoder(in_channels=in_channels_hops, out_channels=hidden_dim_2, selected_hops=range(3))

evaluator = TBXEvaluator(**evaluator_config)
optimizer = TBXOptimizer(**optimizer_config)

# %% [markdown]
# Now we can instantiate the TBXModel.

# %%
model = TBXModel(backbone=backbone,
                 backbone_wrapper=backbone_wrapper,
                 readout=readout,
                 loss=loss,
                 feature_encoder=feature_encoder,
                 evaluator=evaluator,
                 optimizer=optimizer,
                 compile=False)

# %% [markdown]
# ## 6. Training <a class="anchor" id="sec6"></a>

# %% [markdown]
# Now we can use the `lightning` trainer to train the model.

# %%
# Increase the number of epochs to get better results
trainer = pl.Trainer(max_epochs=50, accelerator="cpu", enable_progress_bar=True, log_every_n_steps=1)

trainer.fit(model, datamodule)
train_metrics = trainer.callback_metrics
# Out:
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /Users/martincarrasco/miniconda3/envs/sann_311/lib/python3.11/site-packages/lightning/pytorch/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# /Users/martincarrasco/miniconda3/envs/sann_311/lib/python3.11/site-packages/lightning/pytorch/utilities/parsing.py:43: UserWarning: attribute 'backbone_wrapper' removed from hparams because it cannot be pickled
#   rank_zero_warn(f"attribute '{k}' removed from hparams because it cannot be pickled")
# /Users/martincarrasco/miniconda3/envs/sann_311/lib/python3.11/site-packages/lightning/pytorch/utilities/parsing.py:43: UserWarning: attribute 'loss' removed from hparams because it cannot be pickled
#   rank_zero_warn(f"attribute '{k}' removed from hparams because it cannot be pickled")
#
#   | Name            | Type            | Params
# ----------------------------------------------------
# 0 | feature_encoder | SANNCellEncoder | 8.4 K
# 1 | backbone        | SANNWrapper     | 112 K
# 2 | readout         | SANNReadout     | 45.3 K
# 3 | val_acc_best    | MeanMetric      | 0
# ----------------------------------------------------
# 166 K     Trainable params
# 0         Non-trainable params
# 166 K     Total params
# 0.664     Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# /Users/martincarrasco/miniconda3/envs/sann_311/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:442: PossibleUserWarning: The dataloader, val_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# /Users/martincarrasco/miniconda3/envs/sann_311/lib/python3.11/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The ``compute`` method of metric MulticlassAccuracy was called before the ``update`` method which may lead to errors, as metric states have not yet been updated.
#   warnings.warn(*args, **kwargs)  # noqa: B028
# /Users/martincarrasco/miniconda3/envs/sann_311/lib/python3.11/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The ``compute`` method of metric MulticlassPrecision was called before the ``update`` method which may lead to errors, as metric states have not yet been updated.
#   warnings.warn(*args, **kwargs)  # noqa: B028
# /Users/martincarrasco/miniconda3/envs/sann_311/lib/python3.11/site-packages/torchmetrics/utilities/prints.py:43: UserWarning: The ``compute`` method of metric MulticlassRecall was called before the ``update`` method which may lead to errors, as metric states have not yet been updated.
#   warnings.warn(*args, **kwargs)  # noqa: B028
# /Users/martincarrasco/miniconda3/envs/sann_311/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:442: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# /Users/martincarrasco/miniconda3/envs/sann_311/lib/python3.11/site-packages/lightning/pytorch/trainer/call.py:53: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#   rank_zero_warn("Detected KeyboardInterrupt, attempting graceful shutdown...")

# %%
print('      Training metrics\n', '-'*26)
for key in train_metrics:
    print('{:<21s} {:>5.4f}'.format(key+':', train_metrics[key].item()))
# Out:
#       Training metrics
#  --------------------------
# train/accuracy:       0.0000
# train/precision:      0.2977
# train/recall:         0.5000
# val/loss:             0.0000
# val/accuracy:         0.0000
# val/precision:        0.2991
# val/recall:           0.5000
# train/loss:           0.0000

# %% [markdown]
# ## 7. Testing the model <a class="anchor" id="sec7"></a>

# %% [markdown]
# Finally, we can test the model and obtain the results.

# %%
trainer.test(model, datamodule)
test_metrics = trainer.callback_metrics
# Out:
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃   Runningstage.testing    ┃                           ┃
# ┃          metric           ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │       test/accuracy       │            0.0            │
# │         test/loss         │            0.0            │
# │      test/precision       │    0.2991071343421936     │
# │        test/recall        │            0.5            │
# └───────────────────────────┴───────────────────────────┘

# %%
print('      Testing metrics\n', '-'*25)
for key in test_metrics:
    print('{:<20s} {:>5.4f}'.format(key+':', test_metrics[key].item()))
# Out:
#       Testing metrics
#  -------------------------
# test/loss:           0.0000
# test/accuracy:       0.0000
# test/precision:      0.2991
# test/recall:         0.5000
